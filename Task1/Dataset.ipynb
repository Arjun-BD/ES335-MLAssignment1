# %%
# !pip install pandas
# !pip install numpy
import pandas as pd
import numpy as np

# %%
X_test = np.array(np.load('../X_test.npy'))
X_train = np.array(np.load('../X_train.npy'))
y_test = np.array(np.load('../y_test.npy'))
y_train = np.array(np.load('../y_train.npy'))

# %%
temp_Xtrain = np.sum(X_train**2, axis=2) 
dataframe_Xtrain = pd.DataFrame(temp_Xtrain)

temp_Xtest = np.sum(X_test**2, axis=2) 
dataframe_Xtest = pd.DataFrame(temp_Xtest)
dataframe_Xtrain
# Out:
#           0         1         2         3         4         5         6    \
# 0    2.005249  2.160400  2.273817  2.109540  1.480720  1.188538  1.236224
# 1    1.013713  1.020845  1.025296  1.027185  1.024007  1.022594  1.026870
# 2    1.061579  1.068788  1.076640  1.081619  1.083677  1.089191  1.088519
# 3    0.497171  0.558901  0.629017  0.762178  0.754270  0.740479  0.920398
# 4    0.526393  0.612953  0.625144  0.617296  0.654806  0.651206  0.767416
# ..        ...       ...       ...       ...       ...       ...       ...
# 121  1.667010  1.683330  1.400401  1.398746  1.443760  1.429334  1.422312
# 122  1.030068  1.028156  1.026852  1.031123  1.030664  1.027787  1.030023
# 123  1.017618  1.015693  1.008254  1.003586  1.007235  1.019632  1.024020
# 124  0.737070  0.742623  0.612213  0.611427  0.618866  0.576885  0.663982
# 125  1.962789  2.081590  2.005729  1.920355  1.644706  1.351221  1.413024
#
#           7         8         9    ...       490       491       492  \
# ...

# %%
normalized_Xtrain = (dataframe_Xtrain - dataframe_Xtrain.min()) / (dataframe_Xtrain.max() - dataframe_Xtrain.min())
normalized_Xtrain
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.547192  0.510295  0.653876  0.615205  0.346678  0.274607  0.261360
# 1    0.229558  0.178738  0.239096  0.259088  0.220557  0.226231  0.201821
# 2    0.244891  0.192687  0.256153  0.276998  0.237035  0.245645  0.219353
# 3    0.064086  0.044334  0.107445  0.171895  0.146069  0.143988  0.171541
# 4    0.073447  0.060061  0.106159  0.124226  0.118602  0.117963  0.128034
# ..        ...       ...       ...       ...       ...       ...       ...
# 121  0.438839  0.371490  0.363713  0.381339  0.336472  0.344804  0.314282
# 122  0.234797  0.180865  0.239613  0.260384  0.222396  0.227745  0.202717
# 123  0.230809  0.177239  0.233434  0.251323  0.215926  0.225367  0.201010
# 124  0.140937  0.097789  0.101863  0.122295  0.108678  0.096297  0.098618
# 125  0.533590  0.487366  0.564813  0.552959  0.391963  0.322033  0.311640
#
#           7         8         9    ...       490       491       492  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(dataframe_Xtrain)
scaled_data = scaler.transform(dataframe_Xtrain)
scaled_data
# Out:
# array([[ 1.95714228,  1.98746325,  2.25816764, ..., -1.59492387,
#         -1.47562654, -1.2181764 ],
#        [-0.20585169, -0.23325557, -0.24102482, ..., -0.17321198,
#         -0.20026701, -0.21337435],
#        [-0.10143565, -0.13982592, -0.13824941, ..., -0.04410893,
#         -0.09661299, -0.12869143],
#        ...,
#        [-0.19733364, -0.24329426, -0.27513859, ..., -0.18507563,
#         -0.22690904, -0.21335506],
#        [-0.80933658, -0.77544331, -1.06790146, ..., -1.23628441,
#         -1.2178905 , -1.1419768 ],
#        [ 1.86451802,  1.8338825 ,  1.72152952, ..., -1.17511324,
#         -1.20156305, -1.1292222 ]])
